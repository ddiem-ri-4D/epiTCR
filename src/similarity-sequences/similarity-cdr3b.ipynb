# %%
import pandas as pd
import numpy as np
import sklearn.metrics as metrics
import seaborn as sns
import matplotlib.pyplot as plt
from thefuzz import process, fuzz
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, roc_auc_score, confusion_matrix
from sklearn.model_selection import train_test_split, cross_validate, GridSearchCV
from sklearn.metrics import classification_report, confusion_matrix, plot_roc_curve
from sklearn.metrics import confusion_matrix,accuracy_score,precision_score,recall_score,roc_auc_score,classification_report,roc_curve,auc, f1_score

import pandas as pd
import numpy as np
import sklearn.metrics as metrics
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.metrics import roc_curve, auc
import plotly.graph_objects as go
from itertools import islice
from sklearn.metrics import classification_report, confusion_matrix, plot_roc_curve
from sklearn.metrics import classification_report

# %%
test_data = pd.read_csv("../../predict-full-data/data/prediction_out_full_testdata_nonmhc.csv")
test_data

# %%
test_data = test_data.drop_duplicates(subset=['CDR3b', 'epitope'])
unique_cdr3b = test_data['CDR3b'].unique().tolist()

Input = unique_cdr3b
length_to_split = [10000, 10000, 10000, 10000, 10000, 10000, 10000, 10000, 10000, 10000, 10000, 10000, 10000, 10000, 938]
  
# Using islice
Inputt = iter(Input)
Output = [list(islice(Inputt, elem))
          for elem in length_to_split]

unique_cdr3b_01 = Output[0]
unique_cdr3b_02 = Output[1] 
unique_cdr3b_03 = Output[2]
unique_cdr3b_04 = Output[3]
unique_cdr3b_05 = Output[4]
unique_cdr3b_06 = Output[5]
unique_cdr3b_07 = Output[6]
unique_cdr3b_08 = Output[7]
unique_cdr3b_09 = Output[8]
unique_cdr3b_10 = Output[9]
unique_cdr3b_11 = Output[10]
unique_cdr3b_12 = Output[11]
unique_cdr3b_13 = Output[12]
unique_cdr3b_14 = Output[13]
unique_cdr3b_15 = Output[14]

# %%
score_sort_cdr3_01 = [(x,) + i
             for x in unique_cdr3b_01 
             for i in process.extract(x, unique_cdr3b_01, scorer=fuzz.token_sort_ratio)]

score_sort_cdr3_02 = [(x,) + i
             for x in unique_cdr3b_02 
             for i in process.extract(x, unique_cdr3b_02, scorer=fuzz.token_sort_ratio)]        

score_sort_cdr3_03 = [(x,) + i
             for x in unique_cdr3b_03 
             for i in process.extract(x, unique_cdr3b_03, scorer=fuzz.token_sort_ratio)]    

score_sort_cdr3_04 = [(x,) + i
             for x in unique_cdr3b_04 
             for i in process.extract(x, unique_cdr3b_04, scorer=fuzz.token_sort_ratio)]

score_sort_cdr3_05 = [(x,) + i
             for x in unique_cdr3b_05 
             for i in process.extract(x, unique_cdr3b_05, scorer=fuzz.token_sort_ratio)]

score_sort_cdr3_06 = [(x,) + i
             for x in unique_cdr3b_06 
             for i in process.extract(x, unique_cdr3b_06, scorer=fuzz.token_sort_ratio)]

score_sort_cdr3_07 = [(x,) + i
             for x in unique_cdr3b_07 
             for i in process.extract(x, unique_cdr3b_07, scorer=fuzz.token_sort_ratio)]

score_sort_cdr3_08 = [(x,) + i
             for x in unique_cdr3b_08 
             for i in process.extract(x, unique_cdr3b_08, scorer=fuzz.token_sort_ratio)]

score_sort_cdr3_09 = [(x,) + i
             for x in unique_cdr3b_09 
             for i in process.extract(x, unique_cdr3b_09, scorer=fuzz.token_sort_ratio)]

score_sort_cdr3_10 = [(x,) + i
             for x in unique_cdr3b_10 
             for i in process.extract(x, unique_cdr3b_10, scorer=fuzz.token_sort_ratio)]

score_sort_cdr3_11 = [(x,) + i
             for x in unique_cdr3b_11 
             for i in process.extract(x, unique_cdr3b_11, scorer=fuzz.token_sort_ratio)]

score_sort_cdr3_12 = [(x,) + i
             for x in unique_cdr3b_12 
             for i in process.extract(x, unique_cdr3b_12, scorer=fuzz.token_sort_ratio)]

score_sort_cdr3_13 = [(x,) + i
             for x in unique_cdr3b_13 
             for i in process.extract(x, unique_cdr3b_13, scorer=fuzz.token_sort_ratio)]

score_sort_cdr3_14 = [(x,) + i
             for x in unique_cdr3b_14 
             for i in process.extract(x, unique_cdr3b_14, scorer=fuzz.token_sort_ratio)]

score_sort_cdr3_15 = [(x,) + i
             for x in unique_cdr3b_15 
             for i in process.extract(x, unique_cdr3b_15, scorer=fuzz.token_sort_ratio)]

# %%
similarity_sort_01 = pd.DataFrame(score_sort_cdr3_01, columns=['CDR3b','match_sort','score_sort'])
similarity_sort_02 = pd.DataFrame(score_sort_cdr3_02, columns=['CDR3b','match_sort','score_sort'])
similarity_sort_03 = pd.DataFrame(score_sort_cdr3_03, columns=['CDR3b','match_sort','score_sort'])
similarity_sort_04 = pd.DataFrame(score_sort_cdr3_04, columns=['CDR3b','match_sort','score_sort'])
similarity_sort_05 = pd.DataFrame(score_sort_cdr3_05, columns=['CDR3b','match_sort','score_sort'])
similarity_sort_06 = pd.DataFrame(score_sort_cdr3_06, columns=['CDR3b','match_sort','score_sort'])
similarity_sort_07 = pd.DataFrame(score_sort_cdr3_07, columns=['CDR3b','match_sort','score_sort'])
similarity_sort_08 = pd.DataFrame(score_sort_cdr3_08, columns=['CDR3b','match_sort','score_sort'])
similarity_sort_09 = pd.DataFrame(score_sort_cdr3_09, columns=['CDR3b','match_sort','score_sort'])
similarity_sort_10 = pd.DataFrame(score_sort_cdr3_10, columns=['CDR3b','match_sort','score_sort'])
similarity_sort_11 = pd.DataFrame(score_sort_cdr3_11, columns=['CDR3b','match_sort','score_sort'])
similarity_sort_12 = pd.DataFrame(score_sort_cdr3_12, columns=['CDR3b','match_sort','score_sort'])
similarity_sort_13 = pd.DataFrame(score_sort_cdr3_13, columns=['CDR3b','match_sort','score_sort'])
similarity_sort_14 = pd.DataFrame(score_sort_cdr3_14, columns=['CDR3b','match_sort','score_sort'])
similarity_sort_15 = pd.DataFrame(score_sort_cdr3_15, columns=['CDR3b','match_sort','score_sort'])

# %%
similarity_sort = pd.concat([similarity_sort_01, similarity_sort_02, similarity_sort_03, 
                             similarity_sort_04, similarity_sort_05, similarity_sort_06, 
                             similarity_sort_07, similarity_sort_08, similarity_sort_09, 
                             similarity_sort_10, similarity_sort_11, similarity_sort_12, 
                             similarity_sort_13, similarity_sort_14, similarity_sort_15], axis=0)

similarity_sort['sorted_cdr3_sort'] = np.minimum(similarity_sort['CDR3b'], similarity_sort['match_sort'])

# %%
high_score_sort_50_55 = similarity_sort[(similarity_sort['score_sort'] > 50) & 
                                        (similarity_sort['score_sort'] <= 55) &
                                        (similarity_sort['CDR3b'] != similarity_sort['match_sort']) &
                                        (similarity_sort['sorted_cdr3_sort'] != similarity_sort['match_sort'])]
     
high_score_sort_50_55 = high_score_sort_50_55.drop('sorted_cdr3_sort',axis=1).copy()
high_score_sort_50_55 = high_score_sort_50_55.groupby(['CDR3b','score_sort']).agg(
                        {'match_sort': ', '.join}).sort_values(
                        ['score_sort'], ascending=False)

phigh_score_sort_50_55 = high_score_sort_50_55.copy()
phigh_score_sort_50_55 = phigh_score_sort_50_55.reset_index()
phigh_score_sort_50_55["iCDR3b"] = phigh_score_sort_50_55['CDR3b'].astype(str) +","+ phigh_score_sort_50_55["match_sort"]
phigh_score_sort_50_55["iCDR3b"] = phigh_score_sort_50_55["iCDR3b"].str.split(",")
phigh_score_sort_50_55_exp = phigh_score_sort_50_55.explode("iCDR3b")


high_score_sort_55_60 = similarity_sort[(similarity_sort['score_sort'] > 55) & 
                                        (similarity_sort['score_sort'] <= 60) &
                                        (similarity_sort['CDR3b'] != similarity_sort['match_sort']) &
                                        (similarity_sort['sorted_cdr3_sort'] != similarity_sort['match_sort'])]

high_score_sort_55_60 = high_score_sort_55_60.drop('sorted_cdr3_sort',axis=1).copy()
high_score_sort_55_60 = high_score_sort_55_60.groupby(['CDR3b','score_sort']).agg(
                        {'match_sort': ', '.join}).sort_values(
                        ['score_sort'], ascending=False)

phigh_score_sort_55_60 =  high_score_sort_55_60.copy()
phigh_score_sort_55_60 = phigh_score_sort_55_60.reset_index()
phigh_score_sort_55_60["iCDR3b"] = phigh_score_sort_55_60['CDR3b'].astype(str) +","+ \
                                   phigh_score_sort_55_60["match_sort"]
phigh_score_sort_55_60["iCDR3b"] = phigh_score_sort_55_60["iCDR3b"].str.split(",")
phigh_score_sort_55_60_exp =       phigh_score_sort_55_60.explode("iCDR3b")


high_score_sort_60_65 = similarity_sort[(similarity_sort['score_sort'] > 60) & 
                                        (similarity_sort['score_sort'] <= 65) &
                                        (similarity_sort['CDR3b'] != similarity_sort['match_sort']) &
                                        (similarity_sort['sorted_cdr3_sort'] != similarity_sort['match_sort'])]

high_score_sort_60_65 = high_score_sort_60_65.drop('sorted_cdr3_sort',axis=1).copy()
high_score_sort_60_65 = high_score_sort_60_65.groupby(['CDR3b','score_sort']).agg(
                        {'match_sort': ', '.join}).sort_values(
                        ['score_sort'], ascending=False)

phigh_score_sort_60_65 =  high_score_sort_60_65.copy()
phigh_score_sort_60_65 = phigh_score_sort_60_65.reset_index()
phigh_score_sort_60_65["iCDR3b"] = phigh_score_sort_60_65['CDR3b'].astype(str) +","+ \
                                   phigh_score_sort_60_65["match_sort"]
phigh_score_sort_60_65["iCDR3b"] = phigh_score_sort_60_65["iCDR3b"].str.split(",")
phigh_score_sort_60_65_exp =       phigh_score_sort_60_65.explode("iCDR3b")


high_score_sort_65_70 = similarity_sort[(similarity_sort['score_sort'] > 65) & 
                                        (similarity_sort['score_sort'] <= 70) &
                                        (similarity_sort['CDR3b'] != similarity_sort['match_sort']) &
                                        (similarity_sort['sorted_cdr3_sort'] != similarity_sort['match_sort'])]

high_score_sort_65_70 = high_score_sort_65_70.drop('sorted_cdr3_sort',axis=1).copy()
high_score_sort_65_70 = high_score_sort_65_70.groupby(['CDR3b','score_sort']).agg(
                        {'match_sort': ', '.join}).sort_values(
                        ['score_sort'], ascending=False)

phigh_score_sort_65_70 =  high_score_sort_65_70.copy()
phigh_score_sort_65_70 = phigh_score_sort_65_70.reset_index()
phigh_score_sort_65_70["iCDR3b"] = phigh_score_sort_65_70['CDR3b'].astype(str) +","+ \
                                   phigh_score_sort_65_70["match_sort"]
phigh_score_sort_65_70["iCDR3b"] = phigh_score_sort_65_70["iCDR3b"].str.split(",")
phigh_score_sort_65_70_exp =       phigh_score_sort_65_70.explode("iCDR3b")


high_score_sort_70_75 = similarity_sort[(similarity_sort['score_sort'] > 70) & 
                                        (similarity_sort['score_sort'] <= 75) &
                                        (similarity_sort['CDR3b'] != similarity_sort['match_sort']) &
                                        (similarity_sort['sorted_cdr3_sort'] != similarity_sort['match_sort'])]

high_score_sort_70_75 = high_score_sort_70_75.drop('sorted_cdr3_sort',axis=1).copy()
high_score_sort_70_75 = high_score_sort_70_75.groupby(['CDR3b','score_sort']).agg(
                        {'match_sort': ', '.join}).sort_values(
                        ['score_sort'], ascending=False)

phigh_score_sort_70_75 =  high_score_sort_70_75.copy()
phigh_score_sort_70_75 = phigh_score_sort_70_75.reset_index()
phigh_score_sort_70_75["iCDR3b"] = phigh_score_sort_70_75['CDR3b'].astype(str) +","+ \
                                   phigh_score_sort_70_75["match_sort"]
phigh_score_sort_70_75["iCDR3b"] = phigh_score_sort_70_75["iCDR3b"].str.split(",")
phigh_score_sort_70_75_exp =       phigh_score_sort_70_75.explode("iCDR3b")


high_score_sort_75_80 = similarity_sort[(similarity_sort['score_sort'] > 75) & 
                                        (similarity_sort['score_sort'] <= 80) &
                                        (similarity_sort['CDR3b'] != similarity_sort['match_sort']) &
                                        (similarity_sort['sorted_cdr3_sort'] != similarity_sort['match_sort'])]

high_score_sort_75_80 = high_score_sort_75_80.drop('sorted_cdr3_sort',axis=1).copy()
high_score_sort_75_80 = high_score_sort_75_80.groupby(['CDR3b','score_sort']).agg(
                        {'match_sort': ', '.join}).sort_values(
                        ['score_sort'], ascending=False)

phigh_score_sort_75_80 =  high_score_sort_75_80.copy()
phigh_score_sort_75_80 = phigh_score_sort_75_80.reset_index()
phigh_score_sort_75_80["iCDR3b"] = phigh_score_sort_75_80['CDR3b'].astype(str) +","+ \
                                   phigh_score_sort_75_80["match_sort"]
phigh_score_sort_75_80["iCDR3b"] = phigh_score_sort_75_80["iCDR3b"].str.split(",")
phigh_score_sort_75_80_exp =       phigh_score_sort_75_80.explode("iCDR3b")


high_score_sort_80_85 = similarity_sort[(similarity_sort['score_sort'] > 80) & 
                                        (similarity_sort['score_sort'] <= 85) &
                                        (similarity_sort['CDR3b'] != similarity_sort['match_sort']) &
                                        (similarity_sort['sorted_cdr3_sort'] != similarity_sort['match_sort'])]

high_score_sort_80_85 = high_score_sort_80_85.drop('sorted_cdr3_sort',axis=1).copy()
high_score_sort_80_85 = high_score_sort_80_85.groupby(['CDR3b','score_sort']).agg(
                        {'match_sort': ', '.join}).sort_values(
                        ['score_sort'], ascending=False)

phigh_score_sort_80_85 =  high_score_sort_80_85.copy()
phigh_score_sort_80_85 = phigh_score_sort_80_85.reset_index()
phigh_score_sort_80_85["iCDR3b"] = phigh_score_sort_80_85['CDR3b'].astype(str) +","+ \
                                   phigh_score_sort_80_85["match_sort"]
phigh_score_sort_80_85["iCDR3b"] = phigh_score_sort_80_85["iCDR3b"].str.split(",")
phigh_score_sort_80_85_exp =       phigh_score_sort_80_85.explode("iCDR3b")


high_score_sort_85_90 = similarity_sort[(similarity_sort['score_sort'] > 85) & 
                                        (similarity_sort['score_sort'] <= 90) &
                                        (similarity_sort['CDR3b'] != similarity_sort['match_sort']) &
                                        (similarity_sort['sorted_cdr3_sort'] != similarity_sort['match_sort'])]

high_score_sort_85_90 = high_score_sort_85_90.drop('sorted_cdr3_sort',axis=1).copy()
high_score_sort_85_90 = high_score_sort_85_90.groupby(['CDR3b','score_sort']).agg(
                        {'match_sort': ', '.join}).sort_values(
                        ['score_sort'], ascending=False)

phigh_score_sort_85_90 =  high_score_sort_85_90.copy()
phigh_score_sort_85_90 = phigh_score_sort_85_90.reset_index()
phigh_score_sort_85_90["iCDR3b"] = phigh_score_sort_85_90['CDR3b'].astype(str) +","+ \
                                   phigh_score_sort_85_90["match_sort"]
phigh_score_sort_85_90["iCDR3b"] = phigh_score_sort_85_90["iCDR3b"].str.split(",")
phigh_score_sort_85_90_exp =       phigh_score_sort_85_90.explode("iCDR3b")


high_score_sort_90_95 = similarity_sort[(similarity_sort['score_sort'] > 90) & 
                                        (similarity_sort['score_sort'] <= 95) &
                                        (similarity_sort['CDR3b'] != similarity_sort['match_sort']) &
                                        (similarity_sort['sorted_cdr3_sort'] != similarity_sort['match_sort'])]

high_score_sort_90_95 = high_score_sort_90_95.drop('sorted_cdr3_sort',axis=1).copy()
high_score_sort_90_95 = high_score_sort_90_95.groupby(['CDR3b','score_sort']).agg(
                        {'match_sort': ', '.join}).sort_values(
                        ['score_sort'], ascending=False)

phigh_score_sort_90_95 =  high_score_sort_90_95.copy()
phigh_score_sort_90_95 = phigh_score_sort_90_95.reset_index()
phigh_score_sort_90_95["iCDR3b"] = phigh_score_sort_90_95['CDR3b'].astype(str) +","+ \
                                   phigh_score_sort_90_95["match_sort"]
phigh_score_sort_90_95["iCDR3b"] = phigh_score_sort_90_95["iCDR3b"].str.split(",")
phigh_score_sort_90_95_exp =       phigh_score_sort_90_95.explode("iCDR3b")


high_score_sort_95_100 = similarity_sort[(similarity_sort['score_sort'] > 95) & 
                                        (similarity_sort['score_sort'] <= 100) &
                                        (similarity_sort['CDR3b'] != similarity_sort['match_sort']) &
                                        (similarity_sort['sorted_cdr3_sort'] != similarity_sort['match_sort'])]

high_score_sort_95_100 = high_score_sort_95_100.drop('sorted_cdr3_sort',axis=1).copy()
high_score_sort_95_100 = high_score_sort_95_100.groupby(['CDR3b','score_sort']).agg(
                        {'match_sort': ', '.join}).sort_values(
                        ['score_sort'], ascending=False)

phigh_score_sort_95_100 =  high_score_sort_95_100.copy()
phigh_score_sort_95_100 = phigh_score_sort_95_100.reset_index()
phigh_score_sort_95_100["iCDR3b"] = phigh_score_sort_95_100['CDR3b'].astype(str) +","+ \
                                    phigh_score_sort_95_100["match_sort"]
phigh_score_sort_95_100["iCDR3b"] = phigh_score_sort_95_100["iCDR3b"].str.split(",")
phigh_score_sort_95_100_exp =       phigh_score_sort_95_100.explode("iCDR3b")

# %%
test_data["iCDR3b"] = test_data["CDR3b"]

# %%
data_high_score_sort_50_55  = pd.merge(phigh_score_sort_50_55_exp , test_data, how='left', on='iCDR3b')
data_high_score_sort_55_60  = pd.merge(phigh_score_sort_55_60_exp , test_data, how='left', on='iCDR3b')
data_high_score_sort_60_65  = pd.merge(phigh_score_sort_60_65_exp , test_data, how='left', on='iCDR3b')
data_high_score_sort_65_70  = pd.merge(phigh_score_sort_65_70_exp , test_data, how='left', on='iCDR3b')
data_high_score_sort_70_75  = pd.merge(phigh_score_sort_70_75_exp , test_data, how='left', on='iCDR3b')
data_high_score_sort_75_80  = pd.merge(phigh_score_sort_75_80_exp , test_data, how='left', on='iCDR3b')
data_high_score_sort_80_85  = pd.merge(phigh_score_sort_80_85_exp , test_data, how='left', on='iCDR3b')
data_high_score_sort_85_90  = pd.merge(phigh_score_sort_85_90_exp , test_data, how='left', on='iCDR3b')
data_high_score_sort_90_95  = pd.merge(phigh_score_sort_90_95_exp , test_data, how='left', on='iCDR3b')
data_high_score_sort_95_100 = pd.merge(phigh_score_sort_95_100_exp, test_data, how='left', on='iCDR3b')

similarity_score_sort_50_55  = data_high_score_sort_50_55.copy()
similarity_score_sort_55_60  = data_high_score_sort_55_60.copy()
similarity_score_sort_60_65  = data_high_score_sort_60_65.copy()
similarity_score_sort_65_70  = data_high_score_sort_65_70.copy()
similarity_score_sort_70_75  = data_high_score_sort_70_75.copy()
similarity_score_sort_75_80  = data_high_score_sort_75_80.copy()
similarity_score_sort_80_85  = data_high_score_sort_80_85.copy()
similarity_score_sort_85_90  = data_high_score_sort_85_90.copy()
similarity_score_sort_90_95  = data_high_score_sort_90_95.copy()
similarity_score_sort_95_100 = data_high_score_sort_95_100.copy()

similarity_score_sort_50_55 = similarity_score_sort_50_55.dropna()
similarity_score_sort_55_60 = similarity_score_sort_55_60.dropna()
similarity_score_sort_60_65 = similarity_score_sort_60_65.dropna()
similarity_score_sort_65_70 = similarity_score_sort_65_70.dropna()
similarity_score_sort_70_75 = similarity_score_sort_70_75.dropna()
similarity_score_sort_75_80 = similarity_score_sort_75_80.dropna()
similarity_score_sort_80_85 = similarity_score_sort_80_85.dropna()
similarity_score_sort_85_90 = similarity_score_sort_85_90.dropna()
similarity_score_sort_90_95 = similarity_score_sort_90_95.dropna()
similarity_score_sort_95_100 = similarity_score_sort_95_100.dropna()

similarity_score_sort_50_55  = similarity_score_sort_50_55 .drop_duplicates(subset=['iCDR3b', 'epitope'])
similarity_score_sort_55_60  = similarity_score_sort_55_60 .drop_duplicates(subset=['iCDR3b', 'epitope'])
similarity_score_sort_60_65  = similarity_score_sort_60_65 .drop_duplicates(subset=['iCDR3b', 'epitope'])
similarity_score_sort_65_70  = similarity_score_sort_65_70 .drop_duplicates(subset=['iCDR3b', 'epitope'])
similarity_score_sort_70_75  = similarity_score_sort_70_75 .drop_duplicates(subset=['iCDR3b', 'epitope'])
similarity_score_sort_75_80  = similarity_score_sort_75_80 .drop_duplicates(subset=['iCDR3b', 'epitope'])
similarity_score_sort_80_85  = similarity_score_sort_80_85 .drop_duplicates(subset=['iCDR3b', 'epitope'])
similarity_score_sort_85_90  = similarity_score_sort_85_90 .drop_duplicates(subset=['iCDR3b', 'epitope'])
similarity_score_sort_90_95  = similarity_score_sort_90_95 .drop_duplicates(subset=['iCDR3b', 'epitope'])
similarity_score_sort_95_100 = similarity_score_sort_95_100.drop_duplicates(subset=['iCDR3b', 'epitope'])

similarity_score_sort_50_55  = similarity_score_sort_50_55 .iloc[:, lambda similarity_score_sort_50_55 :[3, 5, 6, 7, 8]]
similarity_score_sort_55_60  = similarity_score_sort_55_60 .iloc[:, lambda similarity_score_sort_55_60 :[3, 5, 6, 7, 8]]
similarity_score_sort_60_65  = similarity_score_sort_60_65 .iloc[:, lambda similarity_score_sort_60_65 :[3, 5, 6, 7, 8]]
similarity_score_sort_65_70  = similarity_score_sort_65_70 .iloc[:, lambda similarity_score_sort_65_70 :[3, 5, 6, 7, 8]]
similarity_score_sort_70_75  = similarity_score_sort_70_75 .iloc[:, lambda similarity_score_sort_70_75 :[3, 5, 6, 7, 8]]
similarity_score_sort_75_80  = similarity_score_sort_75_80 .iloc[:, lambda similarity_score_sort_75_80 :[3, 5, 6, 7, 8]]
similarity_score_sort_80_85  = similarity_score_sort_80_85 .iloc[:, lambda similarity_score_sort_80_85 :[3, 5, 6, 7, 8]]
similarity_score_sort_85_90  = similarity_score_sort_85_90 .iloc[:, lambda similarity_score_sort_85_90 :[3, 5, 6, 7, 8]]
similarity_score_sort_90_95  = similarity_score_sort_90_95 .iloc[:, lambda similarity_score_sort_90_95 :[3, 5, 6, 7, 8]]
similarity_score_sort_95_100 = similarity_score_sort_95_100.iloc[:, lambda similarity_score_sort_95_100:[3, 5, 6, 7, 8]]

# %%
similarity_score_sort_50_55.to_csv ("../../data/similarity-score/cdr3/similarity_score_sort_50_55.csv" , index=False)
similarity_score_sort_55_60.to_csv ("../../data/similarity-score/cdr3/similarity_score_sort_55_60.csv" , index=False)
similarity_score_sort_60_65.to_csv ("../../data/similarity-score/cdr3/similarity_score_sort_60_65.csv" , index=False)
similarity_score_sort_65_70.to_csv ("../../data/similarity-score/cdr3/similarity_score_sort_65_70.csv" , index=False)
similarity_score_sort_70_75.to_csv ("../../data/similarity-score/cdr3/similarity_score_sort_70_75.csv" , index=False)
similarity_score_sort_75_80.to_csv ("../../data/similarity-score/cdr3/similarity_score_sort_75_80.csv" , index=False)
similarity_score_sort_80_85.to_csv ("../../data/similarity-score/cdr3/similarity_score_sort_80_85.csv" , index=False)
similarity_score_sort_85_90.to_csv ("../../data/similarity-score/cdr3/similarity_score_sort_85_90.csv" , index=False)
similarity_score_sort_90_95.to_csv ("../../data/similarity-score/cdr3/similarity_score_sort_90_95.csv" , index=False)
similarity_score_sort_95_100.to_csv("../../data/similarity-score/cdr3/similarity_score_sort_95_100.csv", index=False)

# %%
# similarity_score_sort_50_55 = pd.read_csv("../../data/similarity-score/cdr3/similarity_score_sort_50_55.csv")
# similarity_score_sort_55_60 = pd.read_csv("../../data/similarity-score/cdr3/similarity_score_sort_55_60.csv")
# similarity_score_sort_60_65 = pd.read_csv("../../data/similarity-score/cdr3/similarity_score_sort_60_65.csv")
# similarity_score_sort_65_70 = pd.read_csv("../../data/similarity-score/cdr3/similarity_score_sort_65_70.csv")
# similarity_score_sort_70_75 = pd.read_csv("../../data/similarity-score/cdr3/similarity_score_sort_70_75.csv")
# similarity_score_sort_75_80 = pd.read_csv("../../data/similarity-score/cdr3/similarity_score_sort_75_80.csv")
# similarity_score_sort_80_85 = pd.read_csv("../../data/similarity-score/cdr3/similarity_score_sort_80_85.csv")
# similarity_score_sort_85_90 = pd.read_csv("../../data/similarity-score/cdr3/similarity_score_sort_85_90.csv")
# similarity_score_sort_90_95 = pd.read_csv("../../data/similarity-score/cdr3/similarity_score_sort_90_95.csv")
# similarity_score_sort_95_100= pd.read_csv("../../data/similarity-score/cdr3/similarity_score_sort_95_100.csv")

# %%
y_similarity_50_55  = similarity_score_sort_50_55 ["binder"].to_numpy()
y_similarity_55_60  = similarity_score_sort_55_60 ["binder"].to_numpy()
y_similarity_60_65  = similarity_score_sort_60_65 ["binder"].to_numpy()
y_similarity_65_70  = similarity_score_sort_65_70 ["binder"].to_numpy()
y_similarity_70_75  = similarity_score_sort_70_75 ["binder"].to_numpy()
y_similarity_75_80  = similarity_score_sort_75_80 ["binder"].to_numpy()
y_similarity_80_85  = similarity_score_sort_80_85 ["binder"].to_numpy()
y_similarity_85_90  = similarity_score_sort_85_90 ["binder"].to_numpy()
y_similarity_90_95  = similarity_score_sort_90_95 ["binder"].to_numpy()
y_similarity_95_100 = similarity_score_sort_95_100["binder"].to_numpy()

y_similarity_50_55_pred  = similarity_score_sort_50_55 ["binder_pred"].to_numpy()
y_similarity_55_60_pred  = similarity_score_sort_55_60 ["binder_pred"].to_numpy()
y_similarity_60_65_pred  = similarity_score_sort_60_65 ["binder_pred"].to_numpy()
y_similarity_65_70_pred  = similarity_score_sort_65_70 ["binder_pred"].to_numpy()
y_similarity_70_75_pred  = similarity_score_sort_70_75 ["binder_pred"].to_numpy()
y_similarity_75_80_pred  = similarity_score_sort_75_80 ["binder_pred"].to_numpy()
y_similarity_80_85_pred  = similarity_score_sort_80_85 ["binder_pred"].to_numpy()
y_similarity_85_90_pred  = similarity_score_sort_85_90 ["binder_pred"].to_numpy()
y_similarity_90_95_pred  = similarity_score_sort_90_95 ["binder_pred"].to_numpy()
y_similarity_95_100_pred = similarity_score_sort_95_100["binder_pred"].to_numpy()

# %%
tn01, fp01, fn01, tp01 = confusion_matrix(y_similarity_50_55 , y_similarity_50_55_pred).ravel()
tn02, fp02, fn02, tp02 = confusion_matrix(y_similarity_55_60 , y_similarity_55_60_pred).ravel()
tn03, fp03, fn03, tp03 = confusion_matrix(y_similarity_60_65 , y_similarity_60_65_pred).ravel()
tn04, fp04, fn04, tp04 = confusion_matrix(y_similarity_65_70 , y_similarity_65_70_pred).ravel()
tn05, fp05, fn05, tp05 = confusion_matrix(y_similarity_70_75 , y_similarity_70_75_pred).ravel()
tn06, fp06, fn06, tp06 = confusion_matrix(y_similarity_75_80 , y_similarity_75_80_pred).ravel()
tn07, fp07, fn07, tp07 = confusion_matrix(y_similarity_80_85 , y_similarity_80_85_pred).ravel()
tn08, fp08, fn08, tp08 = confusion_matrix(y_similarity_85_90 , y_similarity_85_90_pred).ravel()
tn09, fp09, fn09, tp09 = confusion_matrix(y_similarity_90_95 , y_similarity_90_95_pred).ravel()
tn10, fp10, fn10, tp10 = confusion_matrix(y_similarity_95_100, y_similarity_95_100_pred).ravel()

accuracy01 = float(accuracy_score(y_similarity_50_55 , y_similarity_50_55_pred).ravel())
accuracy02 = float(accuracy_score(y_similarity_55_60 , y_similarity_55_60_pred).ravel())
accuracy03 = float(accuracy_score(y_similarity_60_65 , y_similarity_60_65_pred).ravel())
accuracy04 = float(accuracy_score(y_similarity_65_70 , y_similarity_65_70_pred).ravel())
accuracy05 = float(accuracy_score(y_similarity_70_75 , y_similarity_70_75_pred).ravel())
accuracy06 = float(accuracy_score(y_similarity_75_80 , y_similarity_75_80_pred).ravel())
accuracy07 = float(accuracy_score(y_similarity_80_85 , y_similarity_80_85_pred).ravel())
accuracy08 = float(accuracy_score(y_similarity_85_90 , y_similarity_85_90_pred).ravel())
accuracy09 = float(accuracy_score(y_similarity_90_95 , y_similarity_90_95_pred).ravel())
accuracy10 = float(accuracy_score(y_similarity_95_100, y_similarity_95_100_pred).ravel())

sensitivity01 = tp01/(tp01+fn01)
sensitivity02 = tp02/(tp02+fn02)
sensitivity03 = tp03/(tp03+fn03)
sensitivity04 = tp04/(tp04+fn04)
sensitivity05 = tp05/(tp05+fn05)
sensitivity06 = tp06/(tp06+fn06)
sensitivity07 = tp07/(tp07+fn07)
sensitivity08 = tp08/(tp08+fn08)
sensitivity09 = tp09/(tp09+fn09)
sensitivity10 = tp10/(tp10+fn10)

specificity01 = tn01/(tn01+fp01)
specificity02 = tn02/(tn02+fp02)
specificity03 = tn03/(tn03+fp03)
specificity04 = tn04/(tn04+fp04)
specificity05 = tn05/(tn05+fp05)
specificity06 = tn06/(tn06+fp06)
specificity07 = tn07/(tn07+fp07)
specificity08 = tn08/(tn08+fp08)
specificity09 = tn09/(tn09+fp09)
specificity10 = tn10/(tn10+fp10)

auc01 = metrics.roc_auc_score(y_similarity_50_55 , similarity_score_sort_50_55 ["predict_proba"])
auc02 = metrics.roc_auc_score(y_similarity_55_60 , similarity_score_sort_55_60 ["predict_proba"])
auc03 = metrics.roc_auc_score(y_similarity_60_65 , similarity_score_sort_60_65 ["predict_proba"])
auc04 = metrics.roc_auc_score(y_similarity_65_70 , similarity_score_sort_65_70 ["predict_proba"])
auc05 = metrics.roc_auc_score(y_similarity_70_75 , similarity_score_sort_70_75 ["predict_proba"])
auc06 = metrics.roc_auc_score(y_similarity_75_80 , similarity_score_sort_75_80 ["predict_proba"])
auc07 = metrics.roc_auc_score(y_similarity_80_85 , similarity_score_sort_80_85 ["predict_proba"])
auc08 = metrics.roc_auc_score(y_similarity_85_90 , similarity_score_sort_85_90 ["predict_proba"])
auc09 = metrics.roc_auc_score(y_similarity_90_95 , similarity_score_sort_90_95 ["predict_proba"])
auc10 = metrics.roc_auc_score(y_similarity_95_100, similarity_score_sort_95_100["predict_proba"])

# %%
data = {'acc': [accuracy01, accuracy02, accuracy03, accuracy04, accuracy05,
                accuracy06,accuracy07,accuracy08,accuracy09,accuracy10,], 
        'sens': [sensitivity01, sensitivity02,sensitivity03, sensitivity04,sensitivity05,
                 sensitivity06,sensitivity07,sensitivity08,sensitivity09,sensitivity10,],
        'spec': [specificity01, specificity02,specificity03, specificity04,specificity05,
                 specificity06,specificity07,specificity08,specificity09,specificity10,], 
        'auc': [auc01, auc02,auc03,auc04,auc05,
                auc06,auc07,auc08,auc09,auc10,]}
df = pd.DataFrame(data=data)
df.to_csv("../../data/output-performance/similarity_cdr3.csv", index=False)

# %%
df
# Out:
#         acc      sens      spec       auc
# 0  0.900000  0.966667  0.880000  0.971000
# 1  0.896552  0.940397  0.890173  0.956896
# 2  0.895332  0.923077  0.893174  0.970011
# 3  0.897374  0.926717  0.895268  0.968413
# 4  0.896915  0.924251  0.895473  0.967615
# 5  0.899919  0.925014  0.898829  0.970269
# 6  0.902645  0.927444  0.901688  0.972554
# 7  0.903542  0.936139  0.902473  0.975804
# 8  0.905180  0.954067  0.903386  0.981575
# 9  0.902842  0.959888  0.901040  0.983062

# %%
prob01 = similarity_score_sort_50_55 ["predict_proba"]
prob02 = similarity_score_sort_55_60 ["predict_proba"]
prob03 = similarity_score_sort_60_65 ["predict_proba"]
prob04 = similarity_score_sort_65_70 ["predict_proba"]
prob05 = similarity_score_sort_70_75 ["predict_proba"]
prob06 = similarity_score_sort_75_80 ["predict_proba"]
prob07 = similarity_score_sort_80_85 ["predict_proba"]
prob08 = similarity_score_sort_85_90 ["predict_proba"]
prob09 = similarity_score_sort_90_95 ["predict_proba"]
prob10 = similarity_score_sort_95_100["predict_proba"]

y_test01 = y_similarity_50_55 .copy()
y_test02 = y_similarity_55_60 .copy()
y_test03 = y_similarity_60_65 .copy()
y_test04 = y_similarity_65_70 .copy()
y_test05 = y_similarity_70_75 .copy()
y_test06 = y_similarity_75_80 .copy()
y_test07 = y_similarity_80_85 .copy()
y_test08 = y_similarity_85_90 .copy()
y_test09 = y_similarity_90_95 .copy()
y_test10 = y_similarity_95_100.copy()

fpr01, tpr01, thresholds = roc_curve(y_test01 , prob01, drop_intermediate=False)
fpr02, tpr02, thresholds = roc_curve(y_test02 , prob02, drop_intermediate=False)
fpr03, tpr03, thresholds = roc_curve(y_test03 , prob03, drop_intermediate=False)
fpr04, tpr04, thresholds = roc_curve(y_test04 , prob04, drop_intermediate=False)
fpr05, tpr05, thresholds = roc_curve(y_test05 , prob05, drop_intermediate=False)
fpr06, tpr06, thresholds = roc_curve(y_test06 , prob06, drop_intermediate=False)
fpr07, tpr07, thresholds = roc_curve(y_test07 , prob07, drop_intermediate=False)
fpr08, tpr08, thresholds = roc_curve(y_test08 , prob08, drop_intermediate=False)
fpr09, tpr09, thresholds = roc_curve(y_test09 , prob09, drop_intermediate=False)
fpr10, tpr10, thresholds = roc_curve(y_test10, prob10, drop_intermediate=False)

auc_score01 = auc(fpr01, tpr01)
auc_score02 = auc(fpr02, tpr02)
auc_score03 = auc(fpr03, tpr03)
auc_score04 = auc(fpr04, tpr04)
auc_score05 = auc(fpr05, tpr05)
auc_score06 = auc(fpr06, tpr06)
auc_score07 = auc(fpr07, tpr07)
auc_score08 = auc(fpr08, tpr08)
auc_score09 = auc(fpr09, tpr09)
auc_score10 = auc(fpr10, tpr10)

aucs = [auc_score01,auc_score02,auc_score03,auc_score04,
        auc_score05,auc_score06,auc_score07,auc_score08,auc_score09, auc_score10]

# %%
def cal_fpr_and_tpr_with_one_cutoff(y_true, y_prred, cutoff):
    tp = np.where(np.logical_and(y_prred >= cutoff, y_true == 1))[0]
    fp = np.where(np.logical_and(y_prred >= cutoff, y_true == 0))[0]
    tpr = len(tp)/len(y_true[y_true==1])
    fpr = len(fp)/len(y_true[y_true==0])
    return fpr,tpr
def cal_fpr_and_tpr_in_different_cutoffs(y_true, y_prred, cutoffs):
    fpr_in_different_cutoffs = []
    tpr_in_different_cutoffs = []
    for cutoff in cutoffs:
        fpr, tpr = cal_fpr_and_tpr_with_one_cutoff(y_true, y_prred, cutoff)
        fpr_in_different_cutoffs.append(fpr)
        tpr_in_different_cutoffs.append(tpr)
    return np.array(fpr_in_different_cutoffs), np.array(tpr_in_different_cutoffs)
def cal_fprs_and_tprs_in_different_sets(y_trues, y_preds, cutoffs):
    fprs_in_different_sets = []
    tprs_in_different_sets = []
    for y_true, y_pred in zip(y_trues, y_preds):
        fprs_in_a_set, tprs_in_a_set = cal_fpr_and_tpr_in_different_cutoffs(y_true, y_pred, cutoffs)
        fprs_in_different_sets.append(fprs_in_a_set)
        tprs_in_different_sets.append(tprs_in_a_set)
    fpr_mean = np.mean(fprs_in_different_sets, axis=0)
    tpr_mean = np.mean(tprs_in_different_sets, axis=0)
    tpr_std= np.std(tprs_in_different_sets, axis=0)
    return fprs_in_different_sets, tprs_in_different_sets
def draw_ROC_Curve(y_trues, y_preds, cutoffs):
    fprs_in_different_sets, tprs_in_different_sets = cal_fprs_and_tprs_in_different_sets(y_trues, y_preds, cutoffs)
    fpr_mean= np.mean(fprs_in_different_sets, axis=0)
    tpr_mean= np.mean(tprs_in_different_sets, axis=0)
    tpr_mean[-1] = 0.0
    tpr_std= np.std(tprs_in_different_sets, axis=0)
    tpr_upper= np.minimum(tpr_mean + tpr_std, 1)
    tpr_lower= np.maximum(tpr_mean - tpr_std, 0)
    fig, ax = plt.subplots(figsize=(12, 9))
    mean_auc = auc(fpr_mean, tpr_mean)
    std_auc = np.std(aucs)
    
    ax.plot(fpr01, tpr01, label = 'Similarity 50-55  (AUC = {0})'.format(round(auc_score01,3)),linewidth=2)
    ax.plot(fpr02, tpr02, label = 'Similarity 55-60  (AUC = {0})'.format(round(auc_score02,3)),linewidth=2)
    ax.plot(fpr03, tpr03, label = 'Similarity 60-65  (AUC = {0})'.format(round(auc_score03,3)),linewidth=2)
    ax.plot(fpr04, tpr04, label = 'Similarity 65-70  (AUC = {0})'.format(round(auc_score04,3)),linewidth=2)
    ax.plot(fpr05, tpr05, label = 'Similarity 70-75  (AUC = {0})'.format(round(auc_score05,3)),linewidth=2)
    ax.plot(fpr06, tpr06, label = 'Similarity 75-80  (AUC = {0})'.format(round(auc_score06,3)),linewidth=2)
    ax.plot(fpr07, tpr07, label = 'Similarity 80-85  (AUC = {0})'.format(round(auc_score07,3)),linewidth=2)
    ax.plot(fpr08, tpr08, label = 'Similarity 85-90  (AUC = {0})'.format(round(auc_score08,3)),linewidth=2)
    ax.plot(fpr09, tpr09, label = 'Similarity 90-95  (AUC = {0})'.format(round(auc_score09,3)),linewidth=2)
    ax.plot(fpr10, tpr10, label = 'Similarity 95-100 ("AUC= {0})'.format(round(auc_score09,3)),linewidth=2)

    ax.plot([0, 1], [0, 1], linestyle="dashed", lw=1, color="k", label="Random guess", alpha=0.8)
    ax.plot(
        fpr_mean,
        tpr_mean,
        color="b",
        lw=0.5,
        label=r"Mean ROC (AUC = %0.3f $\pm$ %0.3f)" % (mean_auc, std_auc),
        alpha=0.8,
    )
    ax.fill_between(
        fpr_mean,
        tpr_lower,
        tpr_upper,
        color="grey",
        alpha=0.5,
        label=r"$\pm$ 1 std. dev.",
    )
    ax.set(
        xlim=[-0.05, 1.05],
        ylim=[-0.05, 1.05],
    )
    ax.legend(loc="lower right")
    plt.title("Impact of sequence similarity on model’s performance with Levenshtein distance", fontsize=11)
    plt.xlabel("False Positive Rate", fontsize=11)
    plt.ylabel("True Positive Rate", fontsize=11)
    plt.rcParams.update({'font.size': 11})
    plt.savefig("../../analysis/figures/benchmark_simi_cdr3.png", dpi=600)
    plt.savefig("../../analysis/figures/benchmark_simi_cdr3.pdf", dpi=600)
    plt.show()
    
draw_ROC_Curve([y_test01,y_test02,y_test03,y_test04,y_test05,
                y_test06,y_test07,y_test08,y_test09, y_test10],
               [prob01,prob02,prob03,prob04,prob05,
                prob06,prob07,prob08,prob09, prob10],np.linspace(0.0, 1.0, num=100))
